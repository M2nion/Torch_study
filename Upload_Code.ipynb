# %% [markdown]
# # git hub 로그인

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Commit_Folder

# !git clone https://M2nion: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@github.com/M2nion/Torch_study.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Commit_Folder
# fatal: destination path 'Torch_study' already exists and is not an empty directory.

# %%
# %cd Torch_study
# Out:
# /content/drive/MyDrive/Commit_Folder/Torch_study

# %%
# !git config --global user.email 'kimkmini@naver.com'
# !git config --global user.name 'M2nion'

# %% [markdown]
# ## 아래 코드는 업로드할 코드명을 넣으면 됨
# ### 파일 전체를 업로드할거면 --all쓰기

# %%
# !git add --all

# %% [markdown]
# # 아래 코드까지 돌리면 github에 업데이트 완료

# %%
# !git commit -m '업로드 완료'
# !git push
# Out:
# [main 642a0f3] 업로드 완료
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 556 bytes | 55.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/M2nion/Torch_study.git
#    4e65b27..642a0f3  main -> main
